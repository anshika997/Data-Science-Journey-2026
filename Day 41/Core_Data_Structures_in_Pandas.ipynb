# %% [markdown]
# # Core Data Structures in Pandas
#
# Pandas is built on two main data structures:
#
# - 1-Series → One-dimensional (like a single column in Excel)
# - 2-DataFrame → Two-dimensional (like a full spreadsheet or SQL table)
#
# ## Series — 1D Labeled Array
#
# A Series is like a list with labels (index).

# %%
import pandas as pd 
s=pd.Series([23,56,57,78,88,79,99,97,99])
print(s)
type(s)
# Out:
# 0    23
# 1    56
# 2    57
# 3    78
# 4    88
# 5    79
# 6    99
# 7    97
# 8    99
# dtype: int64
# pandas.core.series.Series

# %%
s2=pd.Series([23,56,57,78,88,79,99,97,99],index=["harry","akash","keerti","rehan","sanaya","soumya","manshi","anshika","sanya"])

# %%
s2
# Out:
# harry      23
# akash      56
# keerti     57
# rehan      78
# sanaya     88
# soumya     79
# manshi     99
# anshika    97
# sanya      99
# dtype: int64

# %%
s2["anshika"]
# Out:
# 97

# %%
s2["sanya"]
# Out:
# 99

# %% [markdown]
# # DataFrame — 2D Labeled Table
#
# A DataFrame is like a dictionary of Series — multiple columns with labels.

# %%
data = {
    "name":["anshika","sanya","manshi"],
    "age":[23,24,25],
    "city":["satna","indore","bhopal"]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#       name  age    city
# 0  anshika   23   satna
# 1    sanya   24  indore
# 2   manshi   25  bhopal

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')
