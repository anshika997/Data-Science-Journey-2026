# %%
a=34
b=56

# %% [markdown]
# 1 - arithmtic oper.

# %%
a+b#addition
# Out:
# 90

# %%
a-b#substraction
# Out:
# -22

# %%
a*b#multiplication
# Out:
# 1904

# %%
a/b#division
# Out:
# 0.6071428571428571

# %%
a%b#modulus
# Out:
# 34

# %%
a//b#floor division
# Out:
# 0

# %%
a**2#exponentiation
# Out:
# 1156

# %%
a**b# power me convert kr detaa hai
# Out:
# 57918773205287127842044254126179599852840968492056164062843692360166371779746690236416

# %% [markdown]
# 2-now comparision opr..

# %%
a>
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a<=b
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
b!=a
# Out:
# True

# %% [markdown]
# 3- logical operators # always works in boolian

# %%
a1 = True 
a2 = False

# %%
not(a1)#not of a1
# Out:
# False

# %%
not(a2)
# Out:
# True

# %%
a1 or a2
# Out:
# True

# %%
a1 and a2
# Out:
# False

# %% [markdown]
# 4- bitwise oper

# %%
a=5
b=3

# %%
a&b# bits me operate krta h
# Out:
# 1

# %%
a|b
# Out:
# 7

# %% [markdown]
# 5 - assignment oper..

# %%
a=5

# %%
a+=45

# %%
a
# Out:
# 3.0

# %%
a-=3#  now 50 is the value of a

# %%
a
# Out:
# 44

# %%
a*=3

# %%
a# i reinitialed the value of a 5 so it is 5*3
# Out:
# 15

# %%
a/=5

# %%
a
# Out:
# 3.0

# %%
a//=5

# %%
a
# Out:
# 0.0

# %%
a=62

# %%
a%=5

# %%
a
# Out:
# 2

# %%
a**=5

# %%
a
# Out:
# 32

# %% [markdown]
#  membership op..  later with th ehelp of list
