# %% [markdown]
# ordered mutable collections in python

# %%
l=[1,2,3,4,5]

# %%
l[2]
# Out:
# 3

# %%
l[0]=9# as it is mutable the main list can be edited directly

# %%
l# HERE IS THE OUTPUT
# Out:
# [9, 2, 3, 4, 5]

# %% [markdown]
# methods of list

# %%
l2= [11,33,44]
l.extend(l2)
l
# Out:
# [9, 2, 3, 4, 5, 11, 33, 44]

# %%
l.insert(1,200)#insert 200 at iind.. 1

# %%
l
# Out:
# [9, 200, 2, 3, 4, 5, 11, 33, 44]

# %%
l.pop(4)
# Out:
# 4

# %%
number=l.pop(4)

# %%
number
# Out:
# 5

# %%
l
# Out:
# [9, 200, 2, 3, 11, 33, 44]

# %%
l.index(44)
# Out:
# 6

# %%
l.append(4)# add krna

# %%
l
# Out:
# [9, 200, 2, 3, 11, 33, 44, 4]

# %%
l.count(4)
# Out:
# 1

# %%
l.sort() # chng and sort the orignal list in ascending order 
l
# Out:
# [2, 3, 4, 9, 11, 33, 44, 200]

# %%
sorted(l)# returns a new list which is the sorted version of the orignal list
# Out:
# [2, 3, 4, 9, 11, 33, 44, 200]

# %%
newl=[2,6,1,21,6]

# %%
sorted(newl)
# Out:
# [1, 2, 6, 6, 21]

# %%
y =[1,2,True ,False,[4,7]]#nested list

# %%
y
# Out:
# [1, 2, True, False, [4, 7]]

# %%
y[4][0]# y ke 4 item ki 0th item
# Out:
# 4

# %%
list1=[1,23,34,56,4]
list2=[33,32,345,566,6]

# %%
list1+list2# concatination but not chnges the orignal list
# Out:
# [1, 23, 34, 56, 4, 33, 32, 345, 566, 6]

# %%
list1
# Out:
# [1, 23, 34, 56, 4]

# %% [markdown]
# membership

# %%
if 34 in list1:
    print("yes it is there")# return ur print value
# Out:
# yes it is there

# %%
34 in list1# like this return boolean
# Out:
# True

# %%
s= "anshika-singh-bisen-from-bhopal"
s.split("-")
# Out:
# ['anshika', 'singh', 'bisen', 'from', 'bhopal']
