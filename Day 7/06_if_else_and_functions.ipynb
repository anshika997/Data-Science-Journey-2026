# %%
a=400

# %%
if(a>53):
    print("greater")
else:
    print("smaller")
# Out:
# greater

# %%
a=41
if(a>50):
    print("greater than 50")
elif(a>40):
    print("grater than 40")
elif(a>30):
    print("greater than 30")
else:
    print("anshika u can do that lage rho  ")
# Out:
# grater than 40

# %% [markdown]
# if inme se joo bhi cndition phle true ho jaigi toh to ab code direct neeche aa jaigi baki cndition check nhi keregi or koi bhi hota to direct else

# %% [markdown]
# --------now functions in python --------

# %%
def avg(a,b=5):#GIVINGING DEFAULT VLAUE OF B
    return(a+b)/2

# %%
avg(4)
# Out:
# 4.5

# %%
avg(46,6)
# Out:
# 26.0

# %%
def add(a,b):
    return a+b
print(add(3,6))
# Out:
# 9

# %%
def greet():
    print("hello good day")
greet()
# Out:
# hello good day

# %%
None
