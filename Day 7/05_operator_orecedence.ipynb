# %% [markdown]
# btayega kiski precedence phle hai kisiki bad me

# %% [markdown]
# it follows PEMDAS

# %%
10+3*2
# Out:
# 16

# %%
(10+2)*4
# Out:
# 48

# %%
2**3**2
# Out:
# 512

# %%
54*3/23+4-2**5
# Out:
# -20.956521739130434

# %% [markdown]
#  EXPONENTIATIO RUNS **  RIGHT TO LEFT  AND OTHER LEFT TO RIGHT
