# %%
a=input("enter the value of a ")
# Out:
# enter the value of a  45

# %%
a
# Out:
# '45'

# %%
b=input("enter the value of b ")
# Out:
# enter the value of b  45

# %%
a+b# CONCATINATION
# Out:
# '4545'

# %%
int(a)+int(b) # by default it takes user input as a string
# Out:
# 90

# %%
c=input()
# Out:
#  67
