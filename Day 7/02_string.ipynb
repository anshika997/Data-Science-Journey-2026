# %%
name = "anshika"

# %%
name
# Out:
# 'anshika'

# %% [markdown]
# string is the collection of characters  in python

# %% [markdown]
# string methods

# %%
name.upper()
# Out:
# 'ANSHIKA'

# %%
name.endswith('ka')# checks the value of name  ends with ka or not
# Out:
# True

# %%
name.endswith('ishika')# it checks all the character
# Out:
# False

# %%
name.lower()
# Out:
# 'anshika'

# %%
name.count('a')
# Out:
# 2

# %%
name.count('i')
# Out:
# 1

# %%
(len(name))
# Out:
# 7

# %%
print(len(name))
# Out:
# 7

# %%
name[0:5]# index starts with 0
# Out:
# 'anshi'

# %%
name[1:-1]
# Out:
# 'nshik'

# %%
name [1:6]
# Out:
# 'nshik'
