# %%
name ="anshika"
age=19
print("my name is {} and i am {} years old" .format(name,age))
# Out:
# my name is anshika and i am 19 years old

# %% [markdown]
# using format

# %%
print("{0} is runnig {1}".format("anshika", "19"))  # Using positions


print("{name} is runnig {age}".format(name="anshika",age=19)) # keywaard argument
# Out:
# anshika is runnig 19
# anshika is runnig19

# %%
a=5
b=4
print(f"{a} is greater than {b} and the addition of both no. is {a+b}")
# Out:
# 5 is greater than 4 and the addition of both no. is 9

# %% [markdown]
# this is f format more efficient now a days

# %%
pi=3.14159
print(f"pi rounded to 2 decimal places : {pi:.3f}")
# Out:
# pi rounded to 2 decimal places : 3.142

# %% [markdown]
# Formatting Numbers

# %%
print(f"{'python':<10}")# Left-align
print(f"{'python':>10}")  # Right-align
print(f"{'python':^10}") # Center-align
# Out:
# python
#     python
#   python

# %% [markdown]
# Padding and Alignment
#
# :<10 → The < symbol means left-align the text within a total width of 10 characters.
