# %%
import json

# %%
json.dump() – Write JSON data to a fileobj={"name":"anshika","company":"IBM","salary":45000}
json.dumps(obj)# dump s ka mtlb hai dumb as a string
# Out:
# '{"name": "anshika", "company": "IBM", "salary": 45000}'

# %%
obj={"name":"anshika","company":"IBM","salary":45000}
s=json.dumps(obj)
type(s)
# Out:
# str

# %%
print(s)
# Out:
# {"name": "anshika", "company": "IBM", "salary": 45000}

# %% [markdown]
# dumps vo ek python obj ko json string me convert krta h or jo loads h vo ek json string ko python obj.. me cnvert krta h

# %%
d=json.loads('{"name":"anshika","company":"IBM","salary":45000}')
type(d)# convert or load a json string into a python obj..
# Out:
# dict

# %%
print(d)
# Out:
# {'name': 'anshika', 'company': 'IBM', 'salary': 45000}

# %% [markdown]
# json.dump() – Write JSON data to a filee

# %%
file = open("data.json","w")

# %%
json.dump(obj,file)
file.close()

# %%
data = {"name": "Alice", "age": 25, "city": "New York"}

json_string = json.dumps(data)
print(json_string)  # Output: {"name": "Alice", "age": 25, "city": "New York"}
print(type(json_string))  # <class 'str'>
# Out:
# {"name": "Alice", "age": 25, "city": "New York"}
# <class 'str'>

# %%
with open("data.json", "w") as file:
    json.dump(data, file)

# %%
formatted_json = json.dumps(data, indent=4)
print(formatted_json)
# Out:
# {
#     "name": "Alice",
#     "age": 25,
#     "city": "New York"
# }
