# %% [markdown]
# tuple is a immutable collection of element similer to list but to mutable

# %%
e=()
e
# Out:
# ()

# %%
type(e)
# Out:
# tuple

# %%
l=[]

# %%
type(l)
# Out:
# list

# %%
t= (5,6,7,8,9)
t
# Out:
# (5, 6, 7, 8, 9)

# %%
len(t)
# Out:
# 5

# %%
t[1]
# Out:
# 6

# %%
t[5] # index error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 t[5]
#
# IndexError: tuple index out of range

# %%
t[3]=54 # error does not insert any  value bcz it is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 t[3]=54
#
# TypeError: 'tuple' object does not support item assignment

# %%
# packing 
person =("anshika",19,"engineer")
#unpacking 
name,age,profession  = person

# %%
name
# Out:
# 'anshika'

# %%
age
# Out:
# 19

# %%
profession
# Out:
# 'engineer'

# %%
t=(1,2,3)
t.count(2)
# Out:
# 1

# %%
t=(1,2,3)
t.index(2)
# Out:
# 1
