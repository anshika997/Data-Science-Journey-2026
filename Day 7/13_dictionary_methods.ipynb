# %% [markdown]
# A dictionary in Python is an unordered, mutable, and key-value pair collection. It allows efficient data retrieval and modification. Dictionaries in Python are ordered as of Python 3.7

# %%
d={}
type(d)
# Out:
# dict

# %%
student={
"name":"anshika",
"age":19,
"grade":"a"    
}

# %%
student["name"]
# Out:
# 'anshika'

# %% [markdown]
# common mathods

# %%
student.get("name")
# Out:
# 'anshika'

# %%
r=student.get("name1")#error nhi dega none bta dega

# %%
print(r)
# Out:
# None

# %%
student={
"name":"anshika",
"age":19,
"grade":"a"    
}

# %%
print(student["age"])
# Out:
# 19

# %%
student["age"]=20

# %%
(student["age"])
# Out:
# 20

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.values()
# Out:
# dict_values(['anshika', 20, 'a'])

# %%
student.items()
# Out:
# dict_items([('name', 'anshika'), ('age', 20), ('grade', 'a')])

# %%
student.update({"name":"manshi","language":"python"})

# %%
print(student)
# Out:
# {'age': 20, 'grade': 'a', 'language': 'python', 'name': 'no there'}

# %%
student.pop("name")
# Out:
# ' name is no there'

# %%
student.setdefault("name"," name is no there")
# Out:
# ' name is no there'

# %%
 copy_student=student.copy()

# %%
print(copy_student)
# Out:
# {'age': 20, 'grade': 'a', 'language': 'python', 'name': ' name is no there'}
