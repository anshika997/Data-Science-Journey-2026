# %%
a= 30
b=83.8

# %%
a+b
# Out:
# 113

# %%
name ="anshika singh "

# %%
print(name)
# Out:
# anshika singh

# %%
type(name)
# Out:
# str

# %%
print(type(name))# we can  add commment here
# Out:
# <class 'str'>

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
x= "24343"

# %%
y="34345"

# %%
print(x+y)
# Out:
# 2434334345

# %%
print(int(a)+int(b))# type casting force fully we changed the orignal type of the variable
# Out:
# 113

# %%
int(a)+int(b) # type casting
# Out:
# 113
