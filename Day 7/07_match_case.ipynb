# %%
def http_status(code):#code is a variable here 
    match code:
        case 200:
            print("response ok ")
        case 400:
            print("bad request")
        case 404:
            print("not found")
        case _:#defauld value 
            print ("nothing matches ")
print("end of program")
print(http_status(200))
print(http_status(400))
print(http_status(2000))
# Out:
# end of program
# response ok
# None
# bad request
# None
# nothing matches
# None

# %% [markdown]
# it prints none the return value of the statement if we dont want to print none we just need to use http_status(400) dont use print
