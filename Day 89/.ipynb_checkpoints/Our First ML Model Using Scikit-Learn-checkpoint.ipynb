# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\anshika\anaconda3\envs\booksenv\lib\site-packages (0.24.2)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\anshika\anaconda3\envs\booksenv\lib\site-packages (from scikit-learn) (1.5.4)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\anshika\anaconda3\envs\booksenv\lib\site-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\anshika\anaconda3\envs\booksenv\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\anshika\anaconda3\envs\booksenv\lib\site-packages (from scikit-learn) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
features = [[150,0],
            [170,0],
            [130,0],
            [120,1]]

# %%
labels = ["apple","apple","orange","orange"]

# %%
clf = DecisionTreeClassifier()

# %%
clf = clf.fit (features,labels)

# %%
clf.predict([[150,1]])
# Out:
# array(['apple'], dtype='<U6')

# %%
clf.predict([[120,1]])
# Out:
# array(['orange'], dtype='<U6')

# %%
prediction = clf.predict([[150,2]])
print(f"the fruit is {prediction[0]}")
# Out:
# the fruit is apple

# %%
from sklearn.tree import plot_tree

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(11,11))

# %%
plot_tree (clf,feature_names = ["weight","color"], class_names = ["apple","oranges"],filled=True)
# Out:
# [Text(167.4, 163.07999999999998, 'weight <= 140.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = apple'),
#  Text(83.7, 54.360000000000014, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = oranges'),
#  Text(251.10000000000002, 54.360000000000014, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = apple')]
