# %% [markdown]
# # Working with CSVs
# CSV Files
#
# Read CSV

# %%
import pandas as pd
df = pd.read_csv("data.csv")
df
# Out:
#       NAME SCHOOL  MARKS
# 0    anshi    DPS     56
# 1  anshika    DPS     78
# 2    avani    LLS     89
# 3    priya    LLS     89
# 4    aliza    RDS     45
# 5    sanya    RDS     56

# %%
df = df[df['MARKS']>70]

# %%
df
# Out:
#       NAME SCHOOL  MARKS
# 1  anshika    DPS     78
# 2    avani    LLS     89
# 3    priya    LLS     89

# %%
df.to_csv("data_updated.csv")

# %%
df.to_csv("data_updated2.csv",index=False)

# %%
df=pd.read_json("newdata.json")
df
# Out:
#       name  age
# 0  Anshika   20
# 1   Babita   22

# %% [markdown]
# ## Excel Files
# Read Excel

# %%
#  df = pd.read_excel("data.xlsx") 
#  pd.read_excel("data.xlsx", sheet_name="Sales")

# %% [markdown]
# ## Write Excel

# %%
# df.to_excel("output.xlsx", index=False)

# %% [markdown]
# ## Multiple sheets:

# %%
# with pd.ExcelWriter("report.xlsx") as writer:
#     df1.to_excel(writer, sheet_name="Summary", index=False)
#     df2.to_excel(writer, sheet_name="Details", index=False)

# %% [markdown]
# ## Summary
# read_* and to_* methods for CSV, Excel, JSON
# Use sheet_name for Excel

# %%
data = [
    { "Name":'anshika', "Adress":{"city":"bhopal","zipcode":"110001"}},
    { "Name":'priya', "Adress":{"city":"satna","zipcode":"110301"}},
    { "Name":'piya', "Adress":{"city":"bhopal","zipcode":"110201"}},
    { "Name":'riya', "Adress":{"city":"bhopal","zipcode":"110101"}}
]

# %%
data
# Out:
# [{'Name': 'anshika', 'Adress': {'city': 'bhopal', 'zipcode': '110001'}},
#  {'Name': 'priya', 'Adress': {'city': 'satna', 'zipcode': '110301'}},
#  {'Name': 'piya', 'Adress': {'city': 'bhopal', 'zipcode': '110201'}},
#  {'Name': 'riya', 'Adress': {'city': 'bhopal', 'zipcode': '110101'}}]

# %%
type(data)
# Out:
# list

# %%
df = pd.json_normalize(data)
df
# Out:
#       Name Adress.city Adress.zipcode
# 0  anshika      bhopal         110001
# 1    priya       satna         110301
# 2     piya      bhopal         110201
# 3     riya      bhopal         110101

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      object
#  1   Adress.city     4 non-null      object
#  2   Adress.zipcode  4 non-null      object
# dtypes: object(3)
# memory usage: 224.0+ bytes
