# %% [markdown]
# # Functions in MySQL
#
# Functions in MySQL are built-in tools that help you work with data — whether you're manipulating text, performing calculations, or working with dates.
#
# ---
#
# ## 1. CONCAT() – Join strings together
#
# We are telling MySQL to combine two or more strings.
#
# ```sql
# SELECT CONCAT('Hello', ' ', 'World') AS greeting;
# ```
#
# **Output:**
# ```
# Hello World
# ```
#
# You can also use it with columns:
#
# ```sql
# SELECT CONCAT(first_name, ' ', last_name) AS full_name
# FROM users;
# ```
#
# ---
#
# ## 2. NOW() – Get the current date and time
#
# We are telling MySQL to give us the current date and time.
#
# ```sql
# SELECT NOW();
# ```
#
# **Output (example):**
# ```
# 2025-05-03 14:20:45
# ```
#
# ---
#
# ## 3. LENGTH() – Find length of a string (in bytes)
#
# ```sql
# SELECT LENGTH('Harry');
# ```
#
# **Output:**
# ```
# 5
# ```
#
# Useful for validations or checking string size.
#
# ---
#
# ## 4. ROUND() – Round numbers to decimal places
#
# ```sql
# SELECT ROUND(12.6789, 2);
# ```
#
# **Output:**
# ```
# 12.68
# ```
#
# ---
#
# ## 5. DATEDIFF() – Difference between two dates (in days)
#
# ```sql
# SELECT DATEDIFF('2025-06-01', '2025-05-01');
# ```
#
# **Output:**
# ```
# 31
# ```
#
# ---
#
# ## 📋 Comprehensive List of Useful MySQL Functions
#
# | Function        | Description                                 | Example Usage                          |
# |----------------|---------------------------------------------|----------------------------------------|
# | CONCAT()       | Combine multiple strings                    | CONCAT('A', 'B') → 'AB'                |
# | LENGTH()       | Length of string (in bytes)                 | LENGTH('Hi') → 2                       |
# | CHAR_LENGTH()  | Number of characters                        | CHAR_LENGTH('हिंदी') → 5               |
# | LOWER()        | Convert to lowercase                        | LOWER('MySQL') → mysql                 |
# | UPPER()        | Convert to uppercase                        | UPPER('hello') → HELLO                 |
# | REPLACE()      | Replace part of string                      | REPLACE('abc','b','x') → axc           |
# | TRIM()         | Remove spaces                               | TRIM('  hello  ') → hello              |
# | NOW()          | Current date and time                       | NOW()                                  |
# | CURDATE()      | Current date only                           | CURDATE()                              |
# | CURTIME()      | Current time only                           | CURTIME()                              |
# | DATE()         | Extract date                                | DATE(NOW())                            |
# | MONTHNAME()    | Get month name                              | MONTHNAME('2025-05-03') → May          |
# | YEAR()         | Extract year                                | YEAR(NOW())                            |
# | DAY()          | Extract day                                 | DAY('2025-05-03') → 3                  |
# | DATEDIFF()     | Days between dates                          | DATEDIFF('2025-06-01','2025-05-01')    |
# | ROUND()        | Round decimals                              | ROUND(5.678,2) → 5.68                  |
# | FLOOR()        | Round down                                  | FLOOR(5.9) → 5                         |
# | CEIL()         | Round up                                    | CEIL(5.1) → 6                          |
# | ABS()          | Absolute value                              | ABS(-10) → 10                          |
# | MOD()          | Remainder                                   | MOD(10,3) → 1                          |
# | RAND()         | Random number (0 to 1)                      | RAND()                                 |
# | IFNULL()       | Replace NULL                                | IFNULL(NULL,'N/A') → N/A               |
# | COALESCE()     | First non-NULL value                        | COALESCE(NULL,'','Hello') → ''         |
# | COUNT()        | Count rows                                  | COUNT(*)                               |
# | AVG()          | Average value                               | AVG(score)                             |
# | SUM()          | Total sum                                   | SUM(score)                             |
# | MIN()          | Smallest value                              | MIN(score)                             |
# | MAX()          | Largest value                               | MAX(score)                             |
