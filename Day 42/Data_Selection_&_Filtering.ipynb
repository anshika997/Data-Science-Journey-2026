# %% [markdown]
# # Data Selection & Filtering
# Selecting the right rows and columns is the first step in analyzing any dataset. Pandas gives you several powerful ways to do this.
#
# Selecting Rows & ColumnS

# %%
import pandas as pd
import openpyxl

# %%
conda install openpyxl
# Out:
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel(
    r"C:\Users\Anshika\OneDrive\Desktop\Data-Science-Journey-2026\data2.xlsx",
    engine="openpyxl"
)

df.head()
# Out:
#           Actor Name  Age Country        Famous Movie         Awards
# 0  Leonardo DiCaprio   49     USA           Inception          Oscar
# 1  Robert Downey Jr.   59     USA            Iron Man  Oscar Nominee
# 2     Shah Rukh Khan   58   India             Pathaan       Filmfare
# 3        Emma Watson   34      UK        Harry Potter      MTV Award
# 4         Tom Cruise   62     USA  Mission Impossible   Golden Globe

# %%
df ['Actor Name']
# Out:
# 0    Leonardo DiCaprio
# 1    Robert Downey Jr.
# 2       Shah Rukh Khan
# 3          Emma Watson
# 4           Tom Cruise
# Name: Actor Name, dtype: object

# %%
df ['Actor Name'][2]
# Out:
# 'Shah Rukh Khan'

# %%
type(df ['Actor Name'])
# Out:
# pandas.core.series.Series

# %% [markdown]
#  its a copy only ,it doesn't change the original dataframe

# %%
df [['Actor Name','Awards']]
# Out:
#           Actor Name         Awards
# 0  Leonardo DiCaprio          Oscar
# 1  Robert Downey Jr.  Oscar Nominee
# 2     Shah Rukh Khan       Filmfare
# 3        Emma Watson      MTV Award
# 4         Tom Cruise   Golden Globe

# %%
df
# Out:
#           Actor Name  Age Country        Famous Movie         Awards
# 0  Leonardo DiCaprio   49     USA           Inception          Oscar
# 1  Robert Downey Jr.   59     USA            Iron Man  Oscar Nominee
# 2     Shah Rukh Khan   58   India             Pathaan       Filmfare
# 3        Emma Watson   34      UK        Harry Potter      MTV Award
# 4         Tom Cruise   62     USA  Mission Impossible   Golden Globe

# %% [markdown]
# electing Rows by Index
# Use .loc[] (label-based) and .iloc[] (position-based):

# %%
df.loc[1]#we uses the name of the location but in iloc we use the number
# Out:
# Actor Name      Robert Downey Jr.
# Age                            59
# Country                       USA
# Famous Movie             Iron Man
# Awards              Oscar Nominee
# Name: 1, dtype: object

# %%
df.loc[4,'Awards']
# Out:
# 'Golden Globe'

# %%
df.iloc[4,2]# 2 stands for country
# Out:
# 'USA'

# %%
df.loc[0:2,['Awards','Age']]# it include the 2
# Out:
#           Awards  Age
# 0          Oscar   49
# 1  Oscar Nominee   59
# 2       Filmfare   58

# %%
df.iloc[0:2 , 0:1]# it exclude the 2
# Out:
#           Actor Name
# 0  Leonardo DiCaprio
# 1  Robert Downey Jr.

# %% [markdown]
# # Fast Access: .at and .iat
# These are optimized for single element access:

# %%
df.at[0,'Actor Name']# only for accessing a perticular element
# Out:
# 'Leonardo DiCaprio'

# %%
df.iat[0,0]
# Out:
# 'Leonardo DiCaprio'

# %% [markdown]
# # Filtering with Conditions

# %%
df[df['Age']>55]['Actor Name']
# Out:
# 1    Robert Downey Jr.
# 2       Shah Rukh Khan
# 4           Tom Cruise
# Name: Actor Name, dtype: object

# %%
df[(df['Age']>55) & (['Country'])]
# Out:
#           Actor Name  Age Country        Famous Movie         Awards
# 1  Robert Downey Jr.   59     USA            Iron Man  Oscar Nominee
# 2     Shah Rukh Khan   58   India             Pathaan       Filmfare
# 4         Tom Cruise   62     USA  Mission Impossible   Golden Globe

# %% [markdown]
# # Querying with .query()
#
# The .query() method in pandas lets you filter DataFrame rows using a string expression — it's a more readable and often more concise alternative to using boolean indexing.

# %% [markdown]
# #### 1. Column names become variables

# %%
df.query("Age >55 and Awards == 'Filmfare'")
# Out:
#        Actor Name  Age Country Famous Movie    Awards
# 2  Shah Rukh Khan   58   India      Pathaan  Filmfare

# %% [markdown]
# #### 2. String values must be in quotes
# Use single or double quotes around strings in the expression:

# %%
df.query("Awards == 'Filmfare'")
# Out:
#        Actor Name  Age Country Famous Movie    Awards
# 2  Shah Rukh Khan   58   India      Pathaan  Filmfare

# %% [markdown]
# #### 3. Use backticks for column names with spaces or special characters
# If a column name has spaces, use backticks (`):

# %%
df.query("`Actor Name`=='Shah Rukh Khan'")
# Out:
#        Actor Name  Age Country Famous Movie    Awards
# 2  Shah Rukh Khan   58   India      Pathaan  Filmfare

# %% [markdown]
# #### 4. You can use @ to reference Python variables
# To pass external variables into .query():

# %%
age_limit =55
df.query("Age>@age_limit")
# Out:
#           Actor Name  Age Country        Famous Movie         Awards
# 1  Robert Downey Jr.   59     USA            Iron Man  Oscar Nominee
# 2     Shah Rukh Khan   58   India             Pathaan       Filmfare
# 4         Tom Cruise   62     USA  Mission Impossible   Golden Globe

# %% [markdown]
# #### 5. Logical operators
# Use these:
#
# and, or, not — instead of &, |, ~
# ==, !=, <, >, <=, >=

# %%
df.query("Age > 60 and Country =='USA' ")
# Out:
#    Actor Name  Age Country        Famous Movie        Awards
# 4  Tom Cruise   62     USA  Mission Impossible  Golden Globe

# %% [markdown]
# #### 6. Chained comparisons

# %%
df.query("45 <Age<=60 ")
# Out:
#           Actor Name  Age Country Famous Movie         Awards
# 0  Leonardo DiCaprio   49     USA    Inception          Oscar
# 1  Robert Downey Jr.   59     USA     Iron Man  Oscar Nominee
# 2     Shah Rukh Khan   58   India      Pathaan       Filmfare

# %% [markdown]
# #### 7. Avoid using reserved keywords as column names
# If you have a column named class, lambda, etc., you’ll need to use backticks:

# %%
# df.query("`class`==`physics`")  ------>  data is not there ,its just for understanding

# %% [markdown]
# #### 8. Case-sensitive
# Column names and string values are case-sensitive:

# %%
# df.query("country=='USA'")------> we need exact same name (c should be capital)

# %% [markdown]
# #### 9. .query() returns a copy, not a view
# The result is a new DataFrame. Changes won't affect the original unless reassigned:

# %%
filtered = df.query("Age>60")
filtered
# Out:
#    Actor Name  Age Country        Famous Movie        Awards
# 4  Tom Cruise   62     USA  Mission Impossible  Golden Globe

# %% [markdown]
# #### Summary
# Use df[col], .loc[], .iloc[], .at[], .iat[] to access data
# Filter with logical conditions or .query() for readable code
# Mastering selection makes the rest of pandas feel easy

# %%
df2 = df[['Age','Country']].copy() # often use .copy whenever you want to work with copy
df2
# Out:
#    Age Country
# 0   49     USA
# 1   59     USA
# 2   58   India
# 3   34      UK
# 4   62     USA

# %%
df2.loc[0,'Country'] = "pak"

# %%
df2
# Out:
#    Age Country
# 0   49     pak
# 1   59     USA
# 2   58   India
# 3   34      UK
# 4   62     USA

# %%
df
# Out:
#           Actor Name  Age Country        Famous Movie         Awards
# 0  Leonardo DiCaprio   49     USA           Inception          Oscar
# 1  Robert Downey Jr.   59     USA            Iron Man  Oscar Nominee
# 2     Shah Rukh Khan   58   India             Pathaan       Filmfare
# 3        Emma Watson   34      UK        Harry Potter      MTV Award
# 4         Tom Cruise   62     USA  Mission Impossible   Golden Globe
